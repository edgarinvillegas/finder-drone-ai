# %%
# %matplotlib inline

# %%
from urllib.request import urlopen

import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
from albumentations import (
    HorizontalFlip, IAAPerspective, ShiftScaleRotate, CLAHE, RandomRotate90,
    Transpose, ShiftScaleRotate, Blur, OpticalDistortion, GridDistortion, HueSaturationValue,
    IAAAdditiveGaussianNoise, GaussNoise, MotionBlur, MedianBlur, RandomBrightnessContrast, IAAPiecewiseAffine,
    IAASharpen, IAAEmboss, Flip, OneOf, Compose
)

# %%
def download_image(url):
    data = urlopen(url).read()
    data = np.frombuffer(data, np.uint8)
    image = cv2.imdecode(data, cv2.IMREAD_COLOR)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %%
image = download_image('https://d177hi9zlsijyy.cloudfront.net/wp-content/uploads/sites/2/2018/05/11202041/180511105900-atlas-boston-dynamics-robot-running-super-tease.jpg')

# %%
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.show()

# %%
def augment_and_show(aug, image):
    image = aug(image=image)['image']
    plt.figure(figsize=(10, 10))
    plt.imshow(image)

# %%
aug = HorizontalFlip(p=1)
augment_and_show(aug, image)

# %%
aug = IAAPerspective(scale=0.2, p=1)
augment_and_show(aug, image)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-9-025a954e1434> in <module>
#       1 aug = IAAPerspective(scale=0.2, p=1)
# ----> 2 augment_and_show(aug, image)
#
# <ipython-input-7-8410a6cb1a88> in augment_and_show(aug, image)
#       1 def augment_and_show(aug, image):
# ----> 2     image = aug(image=image)['image']
#       3     plt.figure(figsize=(10, 10))
#       4     plt.imshow(image)
#
# c:\users\edgarin\.conda\envs\finder-drone-env\lib\site-packages\albumentations\imgaug\transforms.py in __call__(self, **kwargs)
#      26
#      27     def __call__(self, **kwargs):
# ---> 28         return super(BasicIAATransform, self).__call__(**kwargs)
#      29
#      30     def update_params(self, params, **kwargs):
#
# c:\users\edgarin\.conda\envs\finder-drone-env\lib\site-packages\albumentations\core\transforms_interface.py in __call__(self, force_apply, **kwargs)
#      53         if (random.random() < self.p) or self.always_apply or force_apply:
#      54             params = self.get_params()
# ---> 55             params = self.update_params(params, **kwargs)
#      56             if self.targets_as_params:
#      57                 targets_as_params = {k: kwargs[k] for k in self.targets_as_params}
#
# c:\users\edgarin\.conda\envs\finder-drone-env\lib\site-packages\albumentations\imgaug\transforms.py in update_params(self, params, **kwargs)
#      30     def update_params(self, params, **kwargs):
#      31         params = super(BasicIAATransform, self).update_params(params, **kwargs)
# ---> 32         params['deterministic_processor'] = self.processor.to_deterministic()
#      33         return params
#      34
#
# c:\users\edgarin\.conda\envs\finder-drone-env\lib\site-packages\albumentations\imgaug\transforms.py in processor(self)
#     309     @property
#     310     def processor(self):
# --> 311         return iaa.PerspectiveTransform(self.scale, self.keep_size)
#     312
#     313     def get_transform_init_args_names(self):
#
# c:\users\edgarin\.conda\envs\finder-drone-env\lib\site-packages\imgaug\augmenters\geometric.py in __init__(self, scale, cval, mode, keep_size, name, deterministic, random_state)
#    2130         else:
#    2131             self.cval = iap.handle_discrete_param(cval, "cval", value_range=(0, 255), tuple_to_uniform=True,
# -> 2132                                                   list_to_choice=True, allow_floats=True)
#    2133
#    2134         available_modes = [cv2.BORDER_REPLICATE, cv2.BORDER_CONSTANT]
#
# c:\users\edgarin\.conda\envs\finder-drone-env\lib\site-packages\imgaug\parameters.py in handle_discrete_param(param, name, value_range, tuple_to_uniform, list_to_choice, allow_floats)
#     108         raise Exception(
#     109             "Expected %s, tuple of two %s%s or StochasticParameter for %s, got %s." % (
# --> 110                 allowed_type, allowed_type, list_str, name, type(param),))
#     111
#     112
#
# Exception: Expected number, tuple of two number, list of number or StochasticParameter for cval, got <class 'bool'>.

# %%
aug = ShiftScaleRotate(p=1)
augment_and_show(aug, image)

# %%
def augment_flips_color(p=.5):
    return Compose([
        CLAHE(),
        RandomRotate90(),
        Transpose(),
        ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.50, rotate_limit=45, p=.75),
        Blur(blur_limit=3),
        OpticalDistortion(),
        GridDistortion(),
        HueSaturationValue()
    ], p=p)

# %%
aug = augment_flips_color(p=1)
augment_and_show(aug, image)

# %%
def strong_aug(p=.5):
    return Compose([
        RandomRotate90(),
        Flip(),
        Transpose(),
        OneOf([
            IAAAdditiveGaussianNoise(),
            GaussNoise(),
        ], p=0.2),
        OneOf([
            MotionBlur(p=.2),
            MedianBlur(blur_limit=3, p=0.1),
            Blur(blur_limit=3, p=0.1),
        ], p=0.2),
        ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.2, rotate_limit=45, p=0.2),
        OneOf([
            OpticalDistortion(p=0.3),
            GridDistortion(p=.1),
            IAAPiecewiseAffine(p=0.3),
        ], p=0.2),
        OneOf([
            CLAHE(clip_limit=2),
            IAASharpen(),
            IAAEmboss(),
            RandomBrightnessContrast(),            
        ], p=0.3),
        HueSaturationValue(p=0.3),
    ], p=p)

# %%
aug = strong_aug(p=1)
augment_and_show(aug, image)
